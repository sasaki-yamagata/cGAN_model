# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_history = pd.read_csv("history.csv")
df_history
# Out:
#       d_train_loss  g_train_loss  d_test_loss  g_test_loss
# 0         1.655396      0.804560     6.467573     3.376664
# 1         1.544591      1.683263     6.216370     6.009684
# 2         1.678371      1.441330     6.545733     5.152602
# 3         1.120915      3.287761     4.065141    13.598916
# 4         0.598462      6.771788     2.268045    25.041617
# ...            ...           ...          ...          ...
# 9995      1.394115      0.982322    12.245456     6.371251
# 9996      1.316417      1.006248    11.657992     6.557457
# 9997      1.335985      0.976615    11.710187     6.251699
# 9998      1.402640      0.955208    11.977389     6.187428
# 9999      1.394400      0.929315    12.003490     6.399795
#
# [10000 rows x 4 columns]

# %%
# フォントのサイズの設定
plt.figure(figsize=(10/3, 10/3), dpi=300)
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams["font.size"] = 20
# 軸を内側にする
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.figure(figsize=(9,8))
plt.plot(df_history["g_train_loss"], "b", label="Train")
plt.plot(df_history["g_test_loss"], "r", label="Test")
plt.xlabel('epoch num', fontsize=30)
plt.ylabel('loss', fontsize=30)
plt.legend(loc="upper right")
plt.tight_layout()

# %%
# フォントのサイズの設定
plt.figure(figsize=(10/3, 10/3), dpi=300)
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams["font.size"] = 20
# 軸を内側にする
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.figure(figsize=(9,8))
plt.plot(df_history["d_train_loss"], "b", label="Train")
plt.plot(df_history["d_test_loss"], "r", label="Test")
plt.xlabel('epoch num', fontsize=30)
plt.ylabel('loss', fontsize=30)
plt.legend(loc="upper right")
plt.tight_layout()

# %%
# フォントのサイズの設定
plt.figure(figsize=(10/3, 10/3), dpi=300)
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams["font.size"] = 20
# 軸を内側にする
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.figure(figsize=(9,8))
plt.plot(df_history["g_train_loss"], "b", label="generator_train")
plt.plot(df_history["g_test_loss"], "r", label="generator_test")
plt.plot(df_history["d_train_loss"], "g", label="discriminator_train")
plt.plot(df_history["d_test_loss"], "black", label="discriminator_test")
plt.xlabel('epoch num', fontsize=30)
plt.ylabel('loss', fontsize=30)
plt.legend(loc="upper right")
plt.tight_layout()
